# %%
### Write a program to subtract two complex numbers in Python.
a = complex(3,4)
b = complex(1,2)
c = a -b
print("Subtraction of a & b complex number : ",c)


###---------------------------------------------------------------------#
#Write a program to find the fourth root of a number

number  = 8
#number for 4th Root
rootnumber = 4
#formular for nth root  =number ** (1/n)
forthRoot =  number ** (1/rootnumber)
print(forthRoot)

###---------------------------------------------------------------------#
#Write a program to swap two numbers in Python with the help of a temporary variable.

number1 = int(input("Enter value of first variable: "))
number2 = int(input("Enter value of second variable: "))

tempvariable = number1
number1 = number2
number2 = tempvariable
print ("After Swapping" )
print(number1)
print(number2)

#Write a program to convert fahrenheit to kelvin and celsius both
#Enter Temperature


# 
number1=int(input("Enter value of first variable: "))
number2=int(input("Enter value of second variable: "))
number1=number1+number2
number2=number1-number1
number2=number1-number2
print("number1 is:",number1," number2 is:",number2)

#Write a program to convert fahrenheit to kelvin and celsius both

Temperature = float(input("Enter Temperature in fahrenheit : "))
#formula fahrenheit to kelvin = (32°F − 32) × 5/9 +273.15= 0°K
fahrenheit_to_kelvin =(Temperature-32) * 5/9 + 273.15;

print("fahrenheit to_kelvin:",fahrenheit_to_kelvin)
#formula fahrenheit to celsius = (32°F − 32) × 5/9 = 0°C
fahrenheit_to_celsius= (Temperature-32) * 5/9;
print("fahrenheit to celsius :",fahrenheit_to_celsius)


#Write a program to demonstrate all the available data types in Python. Hint: Use type() function
#Interger
xint = 1
print(type(xint))
#Float
xfloat =1.1
print(type(xfloat))
#Complex
xComplex = 2+3j
print(type(xComplex))
#String
xString ='Mithun Vishwakarma'
print(type(xString))
#List
xList = ["Mithun", "Vishwakarma"]
print(type(xList))
#Tuple
xTuple =("Mithun", "Vishwakarma")
print(type(xTuple))
#Range
xRange =range(6)
print(type(xRange))
#Dictionay
xDict = {"Mithun":"Vishwakarma","Age":33}
print(type(xDict))
#Bool
xBool = True
print(type(xBool))
# Out:
# Subtraction of a & b complex number :  (2+2j)
# 1.681792830507429
# Enter value of first variable: 3
# Enter value of second variable: 4
# After Swapping
# 4
# 3
# Enter value of first variable: 5
# Enter value of second variable: 5
# number1 is: 10  number2 is: 10
# Enter Temperature in fahrenheit : 6
# fahrenheit to_kelvin: 258.7055555555555
# fahrenheit to celsius : -14.444444444444445
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>
# <class 'list'>
# <class 'tuple'>
# <class 'range'>
# <class 'dict'>
# <class 'bool'>

# %% [markdown]
# Create a Markdown cell in jupyter and list the steps discussed in the session by Dr. Darshan
# Ingle sir to create Github profile and upload Githubs Assignment link.
#
# Step1 : Create daywise folder storing you assignment in your PC.
# Step2 : Login to Github using your gmail id
# Step3 : Create new Repository by clicking "+" in menubar in Gihub home page. ex: MithunVishwakarma/LetsUpgrade-AI-ML
# Step4 : Upload you assignment & dragging & dropping particular daywise folder.
