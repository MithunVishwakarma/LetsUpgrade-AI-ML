# %% [markdown]
# Attach the dataset and mentioned problem statement below,
# ● A sizable department has to be maintained, for the purposes of recruiting new talent
# ● More often than not, the new employees have to be trained for the job and/or given time to
# acclimatize themselves to the company
# ● Hence, the management has contracted an HR analytics firm to understand what factors they
# should focus on, in order to curb attrition.
# ● In other words, they want to know what changes they should make to their workplace, in order to
# get most of their employees to stay.
# ● Also, they want to know which of these variables is most important and needs to be addressed
# right away.
#
# Problem Statement A large company named XYZ, employs, at any given point of time, around 4000 employees. However, every year, around 15% of its employees leave the company and need to be replaced with the talent pool available in the job market. The management believes that this level of attrition (employees leaving, either on their own or because they got fired) is bad for the company, because of the following reasons -
#
# The former employees’ projects get delayed, which makes it difficult to meet timelines, resulting in a reputation loss among consumers and partners
# A sizeable department has to be maintained, for the purposes of recruiting new talent
# More often than not, the new employees have to be trained for the job and/or given time to acclimatise themselves to the company
# Hence, the management has contracted an HR analytics firm to understand what factors they should focus on, in order to curb attrition. In other words, they want to know what changes they should make to their workplace, in order to get most of their employees to stay. Also, they want to know which of these variables is most important and needs to be addressed right away.
#
# Since you are one of the star analysts at the firm, this project has been given to you.
#
# Goal of the case study You are required to model the probability of attrition. The results thus obtained will be used by the management to understand what changes they should make to their workplace, in order to get most of their employees to stay.
#
# Columns
# EmployeeIDEmployee number/id
# EnvironmentSatisfactionWork Environment Satisfaction Level
# JobSatisfactionJob Involvement Level Job Involvement Level Job Involvement Level
# WorkLifeBalanceWork life balance level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # for plotting graphs
DS = pd.read_csv("C:\Training\LetsUpgrade\Day7\general_data.csv")
DS.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
DS.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# std       1.106689   47068.888559            2.498887           3.659108
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
# 50%       2.000000   49190.000000            2.000000          14.000000
# 75%       3.000000   83800.000000            4.000000          18.000000
# max       5.000000  199990.000000            9.000000          25.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         4410.0       4410.000000        4401.000000
# mean             8.0          0.793878          11.279936
# std              0.0          0.851883           7.782222
# min              8.0          0.000000           0.000000
# 25%              8.0          0.000000           6.000000
# 50%              8.0          1.000000          10.000000
# 75%              8.0          1.000000          15.000000
# max              8.0          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count            4410.000000     4410.000000              4410.000000
# mean                2.799320        7.008163                 2.187755
# std                 1.288978        6.125135                 3.221699
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        3.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count           4410.000000
# mean               4.123129
# std                3.567327
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000

# %%
DS.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
DS.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4410 non-null   int64
#  1   Attrition                4410 non-null   object
#  2   BusinessTravel           4410 non-null   object
#  3   Department               4410 non-null   object
#  4   DistanceFromHome         4410 non-null   int64
#  5   Education                4410 non-null   int64
#  6   EducationField           4410 non-null   object
#  7   EmployeeCount            4410 non-null   int64
#  8   EmployeeID               4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
#  14  NumCompaniesWorked       4391 non-null   float64
#  15  Over18                   4410 non-null   object
#  16  PercentSalaryHike        4410 non-null   int64
#  17  StandardHours            4410 non-null   int64
#  18  StockOptionLevel         4410 non-null   int64
#  19  TotalWorkingYears        4401 non-null   float64
#  20  TrainingTimesLastYear    4410 non-null   int64
#  21  YearsAtCompany           4410 non-null   int64
#  22  YearsSinceLastPromotion  4410 non-null   int64
#  23  YearsWithCurrManager     4410 non-null   int64
# dtypes: float64(2), int64(14), object(8)
# memory usage: 827.0+ KB

# %%
DS.describe()
# Out:
#                Age  DistanceFromHome    Education  EmployeeCount   EmployeeID  \
# count  4410.000000       4410.000000  4410.000000         4410.0  4410.000000
# mean     36.923810          9.192517     2.912925            1.0  2205.500000
# std       9.133301          8.105026     1.023933            0.0  1273.201673
# min      18.000000          1.000000     1.000000            1.0     1.000000
# 25%      30.000000          2.000000     2.000000            1.0  1103.250000
# 50%      36.000000          7.000000     3.000000            1.0  2205.500000
# 75%      43.000000         14.000000     4.000000            1.0  3307.750000
# max      60.000000         29.000000     5.000000            1.0  4410.000000
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# std       1.106689   47068.888559            2.498887           3.659108
# min       1.000000   10090.000000            0.000000          11.000000
# 25%       1.000000   29110.000000            1.000000          12.000000
# 50%       2.000000   49190.000000            2.000000          14.000000
# 75%       3.000000   83800.000000            4.000000          18.000000
# max       5.000000  199990.000000            9.000000          25.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count         4410.0       4410.000000        4401.000000
# mean             8.0          0.793878          11.279936
# std              0.0          0.851883           7.782222
# min              8.0          0.000000           0.000000
# 25%              8.0          0.000000           6.000000
# 50%              8.0          1.000000          10.000000
# 75%              8.0          1.000000          15.000000
# max              8.0          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count            4410.000000     4410.000000              4410.000000
# mean                2.799320        7.008163                 2.187755
# std                 1.288978        6.125135                 3.221699
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        3.000000                 0.000000
# 50%                 3.000000        5.000000                 1.000000
# 75%                 3.000000        9.000000                 3.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count           4410.000000
# mean               4.123129
# std                3.567327
# min                0.000000
# 25%                2.000000
# 50%                3.000000
# 75%                7.000000
# max               17.000000

# %%
plt.boxplot(DS['DistanceFromHome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250d40a5348>,
#   <matplotlib.lines.Line2D at 0x250d40b9c88>],
#  'caps': [<matplotlib.lines.Line2D at 0x250d40b9d88>,
#   <matplotlib.lines.Line2D at 0x250d40c7908>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250d40aedc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x250d40c7f48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250d40c7ec8>],
#  'means': []}

# %%
plt.boxplot(DS['YearsSinceLastPromotion'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250d41fef88>,
#   <matplotlib.lines.Line2D at 0x250d42036c8>],
#  'caps': [<matplotlib.lines.Line2D at 0x250d4203c48>,
#   <matplotlib.lines.Line2D at 0x250d4203d08>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250d41fe948>],
#  'medians': [<matplotlib.lines.Line2D at 0x250d4209748>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250d4209cc8>],
#  'means': []}

# %%
plt.boxplot(DS['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x250d530b548>,
#   <matplotlib.lines.Line2D at 0x250d530bdc8>],
#  'caps': [<matplotlib.lines.Line2D at 0x250d530be88>,
#   <matplotlib.lines.Line2D at 0x250d530eec8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x250d5301a08>],
#  'medians': [<matplotlib.lines.Line2D at 0x250d530ef88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x250d5313f48>],
#  'means': []}

# %%
DS_Attrition =DS[DS['Attrition']=='Yes']
DS_Attrition.describe()
# Out:
#               Age  DistanceFromHome   Education  EmployeeCount   EmployeeID  \
# count  711.000000        711.000000  711.000000          711.0   711.000000
# mean    33.607595          9.012658    2.877637            1.0  2191.767932
# std      9.675693          7.772368    1.014233            0.0  1270.136654
# min     18.000000          1.000000    1.000000            1.0     2.000000
# 25%     28.000000          2.000000    2.000000            1.0  1072.000000
# 50%     32.000000          7.000000    3.000000            1.0  2165.000000
# 75%     39.000000         15.000000    4.000000            1.0  3341.000000
# max     58.000000         29.000000    5.000000            1.0  4403.000000
#
#          JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  711.000000     711.000000          707.000000         711.000000
# mean     2.037975   61682.616034            2.936351          15.481013
# std      1.057485   44792.067695            2.678774           3.775289
# min      1.000000   10090.000000            0.000000          11.000000
# 25%      1.000000   28440.000000            1.000000          12.000000
# 50%      2.000000   49080.000000            1.000000          14.000000
# 75%      2.000000   71040.000000            5.000000          18.000000
# max      5.000000  198590.000000            9.000000          25.000000
#
#        StandardHours  StockOptionLevel  TotalWorkingYears  \
# count          711.0        711.000000         709.000000
# mean             8.0          0.780591           8.255289
# std              0.0          0.858899           7.164018
# min              8.0          0.000000           0.000000
# 25%              8.0          0.000000           3.000000
# 50%              8.0          1.000000           7.000000
# 75%              8.0          1.000000          10.000000
# max              8.0          3.000000          40.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# count             711.000000      711.000000               711.000000
# mean                2.654008        5.130802                 1.945148
# std                 1.154834        5.941598                 3.148633
# min                 0.000000        0.000000                 0.000000
# 25%                 2.000000        1.000000                 0.000000
# 50%                 3.000000        3.000000                 1.000000
# 75%                 3.000000        7.000000                 2.000000
# max                 6.000000       40.000000                15.000000
#
#        YearsWithCurrManager
# count            711.000000
# mean               2.852321
# std                3.138918
# min                0.000000
# 25%                0.000000
# 50%                2.000000
# 75%                5.000000
# max               14.000000

# %%
left = DS.groupby('Attrition')
left.mean()
# Out:
#                  Age  DistanceFromHome  Education  EmployeeCount   EmployeeID  \
# Attrition
# No         37.561233          9.227088   2.919708            1.0  2208.139497
# Yes        33.607595          9.012658   2.877637            1.0  2191.767932
#
#            JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# Attrition
# No         2.068938   65672.595296            2.648480          15.157340
# Yes        2.037975   61682.616034            2.936351          15.481013
#
#            StandardHours  StockOptionLevel  TotalWorkingYears  \
# Attrition
# No                   8.0          0.796431          11.860780
# Yes                  8.0          0.780591           8.255289
#
#            TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# Attrition
# No                      2.827251        7.369019                 2.234388
# Yes                     2.654008        5.130802                 1.945148
#
#            YearsWithCurrManager
# Attrition
# No                     4.367397
# Yes                    2.852321

# %%
left.describe()
# Out:
#               Age                                                     \
#             count       mean       std   min   25%   50%   75%   max
# Attrition
# No         3699.0  37.561233  8.885956  18.0  31.0  36.0  43.0  60.0
# Yes         711.0  33.607595  9.675693  18.0  28.0  32.0  39.0  58.0
#
#           DistanceFromHome            ... YearsSinceLastPromotion        \
#                      count      mean  ...                     75%   max
# Attrition                             ...
# No                  3699.0  9.227088  ...                     3.0  15.0
# Yes                  711.0  9.012658  ...                     2.0  15.0
#
#           YearsWithCurrManager
#                          count      mean       std  min  25%  50%  75%   max
# Attrition
# No                      3699.0  4.367397  3.593144  0.0  2.0  3.0  7.0  17.0
# Yes                      711.0  2.852321  3.138918  0.0  0.0  2.0  5.0  14.0
#
# [2 rows x 128 columns]

# %%
#Check numnber of employee Left
left_count=DS.groupby('Attrition').count()
plt.bar(left_count.index.values, left_count['Gender'])
plt.xlabel('Employees Left Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
time_spent=DS.groupby('YearsAtCompany').count()
plt.bar(time_spent.index.values, time_spent['EmployeeID'])
plt.xlabel('Number of Years Spend in Company')
plt.ylabel('Number of Employees')
plt.show()

# %%
features=['DistanceFromHome','StandardHours','YearsWithCurrManager','Attrition', 'YearsSinceLastPromotion','JobRole','Gender','BusinessTravel','Education']
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = DS)
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-111-e32f44d57822> in <module>
#       2 fig=plt.subplots(figsize=(10,15))
#       3 for i, j in enumerate(features):
# ----> 4     plt.subplot(4, 2, i+1)
#       5     plt.subplots_adjust(hspace = 1.0)
#       6     sns.countplot(x=j,data = DS)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 8, not 9

# %%
fig=plt.subplots(figsize=(10,15))
for i, j in enumerate(features):
    plt.subplot(4, 2, i+1)
    plt.subplots_adjust(hspace = 1.0)
    sns.countplot(x=j,data = DS, hue='Attrition')
    plt.xticks(rotation=90)
    plt.title("No. of employee")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-4ad3a3eb1f92> in <module>
#       1 fig=plt.subplots(figsize=(10,15))
#       2 for i, j in enumerate(features):
# ----> 3     plt.subplot(4, 2, i+1)
#       4     plt.subplots_adjust(hspace = 1.0)
#       5     sns.countplot(x=j,data = DS, hue='Attrition')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1074
#    1075     fig = gcf()
# -> 1076     a = fig.add_subplot(*args, **kwargs)
#    1077     bbox = a.bbox
#    1078     byebye = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1412                     self._axstack.remove(ax)
#    1413
# -> 1414             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1415
#    1416         return self._add_axes_internal(key, a)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_subplots.py in __init__(self, fig, *args, **kwargs)
#      57                 if num < 1 or num > rows*cols:
#      58                     raise ValueError(
# ---> 59                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      60                 self._subplotspec = GridSpec(
#      61                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 8, not 9

# %% [markdown]
# 1.Sales Executives,Research Scientist,Laboratory Techniciam leave company more frequently than other groups
# 2.Observed employ with 0 & 1 year experience leave more frequenctly than than experienced employee
